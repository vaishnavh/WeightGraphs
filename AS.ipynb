# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import scipy
from scipy import sparse,  io, linalg
import pickle
from tqdm import tqdm_notebook as tqdm
import networkx as nx
import snap
from utils import *
import utils
# %load_ext autoreload
# %autoreload 2

#import imp
#imp.reload(utils)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
G = read_all_graphs('../as/')

# %%
pwl=mutual(G)
plot_log_log_summary(pwl,"Edge Weight", "Mutual Neighbors", B=10,summary=np.median)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#pwl=sim_score_1(G)
pwl=mutual_ew(G)
plot_log_log_summary(pwl,"Edge Weight", "Edge Weighted Mutual Neighbors", B=10,summary=np.median)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#pwl=sim_score_1(oregon_G)
pwl=ewpl(G)
plot_log_log_summary(pwl,"Edge Weight", "Product of incident weights", summary=np.median,B=10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pwl=adamic_acar(G)
plot_log_log_summary(pwl,"Edge Weight", "Adamic Adar", B=10,summary=np.mean)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pwl=adamic_acar_ew(G)
plot_log_log_summary(pwl,"Edge Weight", "Edge Weighted Adamic Adar", B=10,summary=np.mean)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pwl=adamic_acar_ew_2(G)
plot_log_log_summary(pwl,"Edge Weight", "Edge Weighted Adamic Adar", B=10,summary=np.mean)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distances=[0.64,1.0,2.0,4.0,8.0]
pwl = self_similarity(G,distances,size=100)
plot_log_log_summary(np.asarray(pwl),"Radius", "No. of nodes (d=1)",discrete=True,summary=np.mean)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distances=[0.08,0.16,0.32,0.64,1.0,2.0,4.0]
pwl = self_similarity(G,distances,size=100,weight='weight_inv_exp')
plot_log_log_summary(np.asarray(pwl),"Radius", "No. of nodes (d=exp(-w))",discrete=True,summary=np.mean)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
distances=[0.64,1.0,2.0,4.0,8.0]
pwl = self_similarity(G,distances,size=100,weight='weight_inv')
plot_log_log_summary(np.asarray(pwl),"Radius", "No. of nodes (d=1/w)",discrete=True,summary=np.mean)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-007587a39167> in <module>()
#       1 distances=[0.64,1.0,2.0,4.0,8.0]
# ----> 2 pwl = self_similarity(G,distances,size=100,weight='weight_inv')
#       3 plot_log_log_summary(np.asarray(pwl),"Radius", "No. of nodes (d=1/w)",discrete=True,summary=np.mean)
#
# /Users/vaishnan/Documents/15826/code/utils.pyc in self_similarity(G, distances, size, weight)
#     290         for node in tqdm(np.random.choice(G.nodes(),size=size)):
#     291             for d in distances:
# --> 292                 pwl += [(d,len(nx.single_source_dijkstra_path_length(G,node,cutoff=d,weight=weight)))]
#     293     pwl=np.asarray(pwl)
#     294     return pwl
#
# /Users/vaishnan/anaconda2/lib/python2.7/site-packages/networkx/algorithms/shortest_paths/weighted.pyc in single_source_dijkstra_path_length(G, source, cutoff, weight)
#     226         get_weight = lambda u, v, data: data.get(weight, 1)
#     227
# --> 228     return _dijkstra(G, source, get_weight, cutoff=cutoff)
#     229
#     230
#
# /Users/vaishnan/anaconda2/lib/python2.7/site-packages/networkx/algorithms/shortest_paths/weighted.pyc in _dijkstra(G, source, get_weight, pred, paths, cutoff, target)
#     347     push(fringe, (0, next(c), source))
#     348     while fringe:
# --> 349         (d, _, v) = pop(fringe)
#     350         if v in dist:
#     351             continue  # already searched this node.
#
# KeyboardInterrupt:
