# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import scipy
from scipy import sparse,  io, linalg
import pickle
from tqdm import tqdm_notebook as tqdm
import networkx as nx
import snap
from utils import *
# %reload_ext utils

# %%
G = read_all_graphs('../gnutella/')

# %%
#pwl=sim_score_1(G)
plot_log_log_summary(pwl,B=7,summary=np.median)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pwl = sim_score_2(G)
plot_log_log_summary(pwl,B=7,summary=np.mean)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-cf99c4b17d8c> in <module>()
# ----> 1 plot_log_log_summary(sim_score_2(G),B=7,summary=np.mean)
#
# <ipython-input-8-bab59fcf58e2> in sim_score_2(G)
#      12 def sim_score_2(G):
#      13     pwl = []
# ---> 14     for e in tqdm(G.edges()):
#      15         wt = G[e[0]][e[1]]['weight']/float(G.degree(e[0],weight='weight')+G.degree(e[1],weight='weight'))
#      16         nbr1 = set(G.neighbors(e[0]))
#
# /Users/vaishnan/anaconda2/lib/python2.7/site-packages/tqdm/_tqdm_notebook.pyc in __iter__(self, *args, **kwargs)
#     185     def __iter__(self, *args, **kwargs):
#     186         try:
# --> 187             for obj in super(tqdm_notebook, self).__iter__(*args, **kwargs):
#     188                 # return super(tqdm...) will not catch exception
#     189                 yield obj
#
# ...

# %%
distances=[0.16,0.32,0.64,1.0,2.0,4.0]
pwl = self_similarity()

# %%
plot_log_log_summary(np.asarray(pwl),discrete=True,summary=np.mean)

# %%
[1,1,2][:-1]
# Out:
# [1, 1]
